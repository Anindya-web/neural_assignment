# %% [markdown]
# *click to "Connect" from the upper menu. Next click into "Runtime" from above.*

# %% [markdown]
# *click on generate code on the code block message. now write the following prompt "mount drive". then click generate. the following code block will be generated.*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# *now we have to import some libraries.*

# %%
# Import necessary libraries
import cv2
from google.colab.patches import cv2_imshow # To display images in Colab
import numpy as np

# %% [markdown]
# *now we have to read the images. for it we will write the following code block.*

# %%
image = cv2.imread('/content/drive/MyDrive/NEURAL RESEARCH/Practice files/Dataset/Dataset_satelite/1.jpg')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x600>

# %%
height, width, _ = image.shape
print(f"Image size: {width}x{height}")
# Out:
# Image size: 1200x600

# %%
# prompt: resize into 600*500

# Resizing the image
resized_image = cv2.resize(image, (600, 500))

# Display the resized image
cv2_imshow(resized_image)

# Measure the size of the resized image
height_resized, width_resized, _ = resized_image.shape
print(f"Resized image size: {width_resized}x{height_resized}")
# Out:
# <PIL.Image.Image image mode=RGB size=600x500>
# Resized image size: 600x500

# %%
print(image)
# Out:
# [[[ 13  17  18]
#   [ 27  32  31]
#   [ 21  23  23]
#   ...
#   [226 235 239]
#   [228 237 241]
#   [232 241 245]]
#
#  [[ 20  24  25]
#   [ 14  18  19]
#   [ 15  17  17]
#   ...
#   [234 243 247]
#   [233 242 246]
#   [231 240 244]]
#
#  [[ 39  43  44]
#   [ 24  28  29]
#   [ 24  26  26]
#   ...
#   [235 244 247]
#   [229 238 241]
#   [221 230 233]]
#
#  ...
#
#  [[ 47  52  53]
#   [ 33  38  39]
#   [ 24  29  30]
#   ...
#   [222 229 232]
#   [221 228 231]
#   [221 228 231]]
#
#  [[ 22  26  27]
#   [ 13  17  18]
#   [ 13  17  18]
#   ...
#   [221 228 231]
#   [221 228 231]
#   [221 228 231]]
#
#  [[ 33  37  38]
#   [ 32  36  37]
#   [ 40  44  45]
#   ...
#   [220 227 230]
#   [221 228 231]
#   [223 230 233]]]

# %%
print(f"Image orientation: {image.shape}")
print(f"Resized image orientation: {resized_image.shape}")
# Out:
# Image orientation: (600, 1200, 3)
# Resized image orientation: (500, 600, 3)

# %%
# Crop the image
cropped = image[30:250, 30:250] #[start_row:end_row, start_col:end_col]
cv2_imshow(cropped)
# Out:
# <PIL.Image.Image image mode=RGB size=220x220>

# %%
# Crop the image
cropped = image[60:400, 30:250] #[start_row:end_row, start_col:end_col]
cv2_imshow(cropped)
# Out:
# <PIL.Image.Image image mode=RGB size=220x340>

# %%
import os

# Define the input directory and output directory
input_dir = '//content/drive/MyDrive/NEURAL RESEARCH/Practice files/Dataset/Dataset_satelite'
output_dir = '/content/drive/MyDrive/NEURAL RESEARCH/Practice files/Dataset/Resized_Dataset_satelite'

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Define the target size for resizing
target_size = (224, 224)

# Get the list of image files in the input directory
image_files = [f for f in os.listdir(input_dir) if f.endswith(('.png', '.jpg', '.jpeg'))]

# Process each image
for image_file in image_files:
  # Read the image
  img_path = os.path.join(input_dir, image_file)
  image = cv2.imread(img_path)

  if image is not None:
    # Resize the image
    resized_image = cv2.resize(image, target_size)

    # Define the output path
    output_path = os.path.join(output_dir, image_file)

    # Write the resized image to the output directory
    cv2.imwrite(output_path, resized_image)

    print(f"Processed and saved: {image_file}")
  else:
    print(f"Could not read image: {image_file}")

print("Finished processing all images.")
# Out:
# Processed and saved: 10.jpg
# Processed and saved: 1.jpg
# Processed and saved: 11.jpg
# Processed and saved: 18.jpg
# Processed and saved: 12.jpg
# Processed and saved: 16.jpg
# Processed and saved: 15.jpg
# Processed and saved: 14.jpg
# Processed and saved: 13.jpg
# Processed and saved: 17.jpg
# Processed and saved: 20.jpg
# Processed and saved: 23.jpg
# Processed and saved: 33.jpg
# Processed and saved: 29.jpg
# Processed and saved: 2.jpg
# Processed and saved: 28.jpg
# Processed and saved: 25.jpg
# Processed and saved: 21.jpg
# Processed and saved: 30.jpg
# Processed and saved: 19.jpg
# Processed and saved: 22.jpg
# Processed and saved: 24.jpg
# Processed and saved: 3.jpg
# Processed and saved: 26.jpg
# Processed and saved: 32.jpg
# Processed and saved: 27.jpg
# Processed and saved: 31.jpg
# Processed and saved: 35.jpg
# Processed and saved: 4.jpg
# Processed and saved: 38.jpg
# Processed and saved: 40.jpg
# Processed and saved: 39.jpg
# Processed and saved: 47.jpg
# Processed and saved: 44.jpg
# Processed and saved: 41.jpg
# Processed and saved: 43.jpg
# Processed and saved: 34.jpg
# Processed and saved: 48.jpg
# Processed and saved: 37.jpg
# Processed and saved: 46.jpg
# Processed and saved: 36.jpg
# Processed and saved: 45.jpg
# Processed and saved: 42.jpg
# Processed and saved: 50.jpg
# Processed and saved: 6.jpg
# Processed and saved: 49.jpg
# Processed and saved: 5.jpg
# Processed and saved: 7.jpg
# Processed and saved: 8.jpg
# Processed and saved: 9.jpg
# Finished processing all images.

# %%
import os

# Define the input directory and output directory
input_dir = '/content/drive/MyDrive/NEURAL RESEARCH/Practice files/Dataset/Dataset_satelite'
output_dir = '/content/drive/MyDrive/NEURAL RESEARCH/Practice files/Dataset/Cropped_Dataset_satelite'

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Define the target size for cropping
cropped = image[60:400, 30:250] #[start_row:end_row, start_col:end_col]

# start_row = 60
# end_row = 400
# start_col = 30
# end_col = 250

# Get the list of image files in the input directory
image_files = [f for f in os.listdir(input_dir) if f.endswith(('.png', '.jpg', '.jpeg'))]

# Process each image
for image_file in image_files:
  # Read the image
  img_path = os.path.join(input_dir, image_file)
  image = cv2.imread(img_path)

  if image is not None:
    # cropped the image
    cropped_image = image

    # Define the output path
    output_path = os.path.join(output_dir, image_file)

    # Write the cropped image to the output directory
    cv2.imwrite(output_path, resized_image)

    print(f"Cropped and saved: {image_file}")
  else:
    print(f"Could not read image: {image_file}")

print("Finished processing all images.")
# Out:
# Cropped and saved: 10.jpg
# Cropped and saved: 1.jpg
# Cropped and saved: 11.jpg
# Cropped and saved: 18.jpg
# Cropped and saved: 12.jpg
# Cropped and saved: 16.jpg
# Cropped and saved: 15.jpg
# Cropped and saved: 14.jpg
# Cropped and saved: 13.jpg
# Cropped and saved: 17.jpg
# Cropped and saved: 20.jpg
# Cropped and saved: 23.jpg
# Cropped and saved: 33.jpg
# Cropped and saved: 29.jpg
# Cropped and saved: 2.jpg
# Cropped and saved: 28.jpg
# Cropped and saved: 25.jpg
# Cropped and saved: 21.jpg
# Cropped and saved: 30.jpg
# Cropped and saved: 19.jpg
# Cropped and saved: 22.jpg
# Cropped and saved: 24.jpg
# Cropped and saved: 3.jpg
# Cropped and saved: 26.jpg
# Cropped and saved: 32.jpg
# Cropped and saved: 27.jpg
# Cropped and saved: 31.jpg
# Cropped and saved: 35.jpg
# Cropped and saved: 4.jpg
# Cropped and saved: 38.jpg
# Cropped and saved: 40.jpg
# Cropped and saved: 39.jpg
# Cropped and saved: 47.jpg
# Cropped and saved: 44.jpg
# Cropped and saved: 41.jpg
# Cropped and saved: 43.jpg
# Cropped and saved: 34.jpg
# Cropped and saved: 48.jpg
# Cropped and saved: 37.jpg
# Cropped and saved: 46.jpg
# Cropped and saved: 36.jpg
# Cropped and saved: 45.jpg
# Cropped and saved: 42.jpg
# Cropped and saved: 50.jpg
# Cropped and saved: 6.jpg
# Cropped and saved: 49.jpg
# Cropped and saved: 5.jpg
# Cropped and saved: 7.jpg
# Cropped and saved: 8.jpg
# Cropped and saved: 9.jpg
# Finished processing all images.
